# %% [markdown]
# #### 1. Найти фичи или каналы, которые использует компания
# #### 2. Построить модель, которая предсказывает продажи
# #### 3. Разбить датасет на обучающую и тестовые части
# #### 4. Подсчитать среднеквадратическую ошибку

# %% [markdown]
# ### Import Data

# %%
#import the required libraries
import pandas as pd

# %%
df_ad_budget_data = pd.read_csv('C:\Project1\Advertising+Budget+and+Sales.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Deifo\AppData\Local\Temp\ipykernel_12768\1766609111.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df_ad_budget_data = pd.read_csv('C:\Project1\Advertising+Budget+and+Sales.csv')

# %%
df_ad_budget_data
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 1             2              44.5                 39.3
# 2             3              17.2                 45.9
# 3             4             151.5                 41.3
# 4             5             180.8                 10.8
# ..          ...               ...                  ...
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 1                       45.1       10.4
# 2                       69.3        9.3
# 3                       58.5       18.5
# 4                       58.4       12.9
# ..                       ...        ...
# 195                     13.8        7.6
# 196                      8.1        9.7
# 197                      6.4       12.8
# 198                     66.2       25.5
# 199                      8.7       13.4
#
# [200 rows x 5 columns]

# %%
df_ad_budget_data[df_ad_budget_data['Sales ($)']>22]
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 15           16             195.4                 47.7
# 17           18             281.4                 39.6
# 36           37             266.9                 43.8
# 47           48             239.9                 41.5
# 52           53             216.4                 41.7
# 55           56             198.9                 49.4
# 58           59             210.8                 49.6
# 61           62             261.3                 42.7
# 69           70             216.8                 43.9
# 93           94             250.9                 36.5
# 98           99             289.7                 42.3
# 101         102             296.4                 36.3
# 128         129             220.3                 49.0
# 147         148             243.2                 49.0
# 175         176             276.9                 48.9
# 183         184             287.6                 43.0
# 185         186             205.0                 45.1
# 198         199             283.6                 42.0
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 15                      52.9       22.4
# 17                      55.8       24.4
# 36                       5.0       25.4
# 47                      18.5       23.2
# 52                      39.6       22.6
# 55                      60.0       23.7
# 58                      37.7       23.8
# 61                      54.7       24.2
# 69                      27.2       22.3
# 93                      72.3       22.2
# 98                      51.2       25.4
# 101                    100.9       23.8
# 128                      3.2       24.7
# 147                     44.3       25.4
# 175                     41.8       27.0
# 183                     71.8       26.2
# 185                     19.6       22.6
# 198                     66.2       25.5

# %%
 df_ad_budget_data[(df_ad_budget_data['Sales ($)']>22) & (df_ad_budget_data['TV Ad Budget ($)']>250)]
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 17           18             281.4                 39.6
# 36           37             266.9                 43.8
# 61           62             261.3                 42.7
# 93           94             250.9                 36.5
# 98           99             289.7                 42.3
# 101         102             296.4                 36.3
# 175         176             276.9                 48.9
# 183         184             287.6                 43.0
# 198         199             283.6                 42.0
#
#      Newspaper Ad Budget ($)  Sales ($)
# 17                      55.8       24.4
# 36                       5.0       25.4
# 61                      54.7       24.2
# 93                      72.3       22.2
# 98                      51.2       25.4
# 101                    100.9       23.8
# 175                     41.8       27.0
# 183                     71.8       26.2
# 198                     66.2       25.5

# %%
df_ad_budget_data.loc[0:4]
# Out:
#    Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  \
# 0           1             230.1                 37.8                     69.2
# 1           2              44.5                 39.3                     45.1
# 2           3              17.2                 45.9                     69.3
# 3           4             151.5                 41.3                     58.5
# 4           5             180.8                 10.8                     58.4
#
#    Sales ($)
# 0       22.1
# 1       10.4
# 2        9.3
# 3       18.5
# 4       12.9

# %%
df_ad_budget_data.loc[10:15, 'TV Ad Budget ($)':'Newspaper Ad Budget ($)']
# Out:
#     TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 10              66.1                  5.8                     24.2
# 11             214.7                 24.0                      4.0
# 12              23.8                 35.1                     65.9
# 13              97.5                  7.6                      7.2
# 14             204.1                 32.9                     46.0
# 15             195.4                 47.7                     52.9

# %%
df_ad_budget_data.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
df_ad_budget_data.columns
# Out:
# Index(['Unnamed: 0', 'TV Ad Budget ($)', 'Radio Ad Budget ($)',
#        'Newspaper Ad Budget ($)', 'Sales ($)'],
#       dtype='object')

# %%
df_ad_budget_data_ind = pd.read_csv('C:\Project1\Advertising+Budget+and+Sales.csv', index_col = 0)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Deifo\AppData\Local\Temp\ipykernel_12768\2755599555.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df_ad_budget_data_ind = pd.read_csv('C:\Project1\Advertising+Budget+and+Sales.csv', index_col = 0)

# %%
df_ad_budget_data_ind
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 1               230.1                 37.8                     69.2       22.1
# 2                44.5                 39.3                     45.1       10.4
# 3                17.2                 45.9                     69.3        9.3
# 4               151.5                 41.3                     58.5       18.5
# 5               180.8                 10.8                     58.4       12.9
# ..                ...                  ...                      ...        ...
# 196              38.2                  3.7                     13.8        7.6
# 197              94.2                  4.9                      8.1        9.7
# 198             177.0                  9.3                      6.4       12.8
# 199             283.6                 42.0                     66.2       25.5
# 200             232.1                  8.6                      8.7       13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Analyze the dataset

# %%
#view the initial few records of the dataset
df_ad_budget_data_ind.head()
# Out:
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 1             230.1                 37.8                     69.2       22.1
# 2              44.5                 39.3                     45.1       10.4
# 3              17.2                 45.9                     69.3        9.3
# 4             151.5                 41.3                     58.5       18.5
# 5             180.8                 10.8                     58.4       12.9

# %%
#check the total number elements in the dataset
df_ad_budget_data_ind.size
# Out:
# 800

# %% [markdown]
# ### Find the features of media channels used by the firm

# %%
df_ad_budget_data_ind.shape
# Out:
# (200, 4)

# %%
df_ad_budget_data_ind.columns
# Out:
# Index(['TV Ad Budget ($)', 'Radio Ad Budget ($)', 'Newspaper Ad Budget ($)',
#        'Sales ($)'],
#       dtype='object')

# %% [markdown]
# ### Create objects to train and test the model

# %%
#create a feature object from the model
X_features = df_ad_budget_data_ind[['TV Ad Budget ($)', 'Radio Ad Budget ($)', 'Newspaper Ad Budget ($)']]

# %%
#view the feature object
X_features.head()
# Out:
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 1             230.1                 37.8                     69.2
# 2              44.5                 39.3                     45.1
# 3              17.2                 45.9                     69.3
# 4             151.5                 41.3                     58.5
# 5             180.8                 10.8                     58.4

# %%
#create a target object
Y_target = df_ad_budget_data_ind[['Sales ($)']]

# %%
Y_target.head()
# Out:
#    Sales ($)
# 1       22.1
# 2       10.4
# 3        9.3
# 4       18.5
# 5       12.9

# %%
#verify if all the observations have been captured in the feature object
X_features.shape
# Out:
# (200, 3)

# %%
#verify if all the observations have been captured in the target object
Y_target.shape
# Out:
# (200, 1)

# %% [markdown]
# ### Split the dataset into training and testing dataset for the model

# %%
#split the dataset (by default, 75% is the training data and 25% is the testing data)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_features, Y_target, random_state = 27)

# %%
#verify if the training and testing dataset are split correctly
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (150, 3)
# (50, 3)
# (150, 1)
# (50, 1)

# %% [markdown]
# ### Create a model to predict the sales outcome

# %%
#create a linear regression model
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#sales = constant + coef1 * (TV budget) + coef2 * (Radio budget) + coef3 * (Newspaper budget)
#print coefficient
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# [2.79916791]
# [[0.04648022 0.1845547  0.00286741]]

# %%
#sales = 2.79916791 + 0.04648022 * (TV budget) + 0.1845547 * (Radio budget) + 0.00286741 * (Newspaper budget)
#predict the outcome for the testing dataset
y_pred = linreg.predict(x_test)

# %%
y_pred
# Out:
# array([[14.75846783],
#        [16.41852084],
#        [16.41759144],
#        [12.03709252],
#        [20.70723013],
#        [17.29565452],
#        [14.96988622],
#        [19.65050706],
#        [23.56456091],
#        [11.97347741],
#        [19.50018553],
#        [12.76087618],
#        [10.57222916],
#        [18.94036675],
#        [ 8.59530013],
#        [21.85921162],
#        [12.62654629],
#        [14.56942078],
#        [ 9.97244579],
#        [16.37300148],
#        [15.78422833],
#        [13.0595913 ],
#        [14.24547458],
#        [17.10679479],
#        [18.06357979],
#        [10.40616358],
#        [ 9.69680278],
#        [10.48598218],
#        [16.34460782],
#        [11.46674105],
#        [10.58161139],
#        [ 8.17350495],
#        [ 9.10425404],
#        [ 7.90763047],
#        [23.2733627 ],
#        [ 4.44591202],
#        [ 4.43201673],
#        [ 9.83072166],
#        [12.90035894],
#        [13.42658867],
#        [15.33659361],
#        [19.64025587],
#        [ 7.72524213],
#        [15.61866872],
#        [17.98812442],
#        [13.69839908],
#        [ 6.54033781],
#        [10.97508723],
#        [ 5.29713478],
#        [ 5.1469155 ]])

# %%
y_test
# Out:
#      Sales ($)
# 104       14.7
# 49        14.8
# 41        16.6
# 149       10.9
# 186       22.6
# 75        17.0
# 163       14.9
# 110       19.8
# 102       23.8
# 174       11.7
# 140       20.7
# 198       12.8
# 13         9.2
# 69        18.9
# 79         5.3
# 59        23.8
# 10        10.6
# 166       11.9
# 91        11.2
# 96        16.9
# 132       12.7
# 64        14.0
# 161       14.4
# 28        15.9
# 60        18.4
# 95        11.5
# 146       10.3
# 127        6.6
# 195       17.3
# 87        12.0
# 181       10.5
# 50         9.7
# 126       10.6
# 130        9.7
# 148       25.4
# 193        5.9
# 77         6.9
# 39        10.1
# 116       12.6
# 168       12.2
# 157       15.3
# 125       19.7
# 66         9.3
# 88        16.0
# 170       15.0
# 123       11.6
# 118        9.4
# 165       11.9
# 196        7.6
# 156        3.2

# %%
y_check = y_test

# %%
y_check['Sales prediction($)'] = y_pred

# %%
y_check
# Out:
#      Sales ($)  Sales prediction($)
# 104       14.7            14.758468
# 49        14.8            16.418521
# 41        16.6            16.417591
# 149       10.9            12.037093
# 186       22.6            20.707230
# 75        17.0            17.295655
# 163       14.9            14.969886
# 110       19.8            19.650507
# 102       23.8            23.564561
# 174       11.7            11.973477
# 140       20.7            19.500186
# 198       12.8            12.760876
# 13         9.2            10.572229
# 69        18.9            18.940367
# 79         5.3             8.595300
# 59        23.8            21.859212
# 10        10.6            12.626546
# 166       11.9            14.569421
# 91        11.2             9.972446
# 96        16.9            16.373001
# 132       12.7            15.784228
# 64        14.0            13.059591
# 161       14.4            14.245475
# 28        15.9            17.106795
# 60        18.4            18.063580
# 95        11.5            10.406164
# 146       10.3             9.696803
# 127        6.6            10.485982
# 195       17.3            16.344608
# 87        12.0            11.466741
# 181       10.5            10.581611
# 50         9.7             8.173505
# 126       10.6             9.104254
# 130        9.7             7.907630
# 148       25.4            23.273363
# 193        5.9             4.445912
# 77         6.9             4.432017
# 39        10.1             9.830722
# 116       12.6            12.900359
# 168       12.2            13.426589
# 157       15.3            15.336594
# 125       19.7            19.640256
# 66         9.3             7.725242
# 88        16.0            15.618669
# 170       15.0            17.988124
# 123       11.6            13.698399
# 118        9.4             6.540338
# 165       11.9            10.975087
# 196        7.6             5.297135
# 156        3.2             5.146916

# %% [markdown]
# ### Calculate the Mean Square Error (MSE)

# %%
from sklearn import metrics
import numpy as np

# %%
#calculate the MSE
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 2.497299615877589

# %%
#calculate the RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 1.5802846629255087
